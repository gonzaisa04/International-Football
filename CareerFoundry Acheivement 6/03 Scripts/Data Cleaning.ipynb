# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\asus\CareerFoundry\CareerFoundry Acheivement 6'

# %%
rgs_1 = pd.read_csv(os.path.join(path, '02 Data','Prepared Data', 'rgs_csv'), index_col = 0)

# %%
rgs.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral team scorer  minute own_goal penalty winner  \
# 0  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 1   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 2  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 3   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 4  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
#
#   first_shooter match_time match_winner
# 0           NaN        NaN         draw
# ...

# %%
rgs = rgs.drop(columns = 'Unnamed: 0')

# %%
rgs.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral team scorer  minute own_goal penalty winner  \
# 0  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 1   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 2  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 3   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 4  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
#
#   first_shooter match_time
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
rgs.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'rgs_csv'))

# %%
rgs_1 = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'rgs_csv'), index_col = 0)

# %%
rgs_1.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral team scorer  minute own_goal penalty winner  \
# 0  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 1   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 2  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 3   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 4  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
#
#   first_shooter match_time match_winner
# 0           NaN        NaN         draw
# ...

# %%
def match_winner(row):
    if row ['home_score'] < ['away_score']:
        return 'away win'
    elif row['home_score'] > ['away_score']:
        return 'home win'
    else: return 'draw'

# %%
rgs_1['match_winner'] = rgs_1.apply(match_winner, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 rgs_1['match_winner'] = rgs_1.apply(match_winner, axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# ...

# %%
df['match_winner'].value_counts(dropna = False)

# %%
rgs_1.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral team scorer  minute own_goal penalty winner  \
# 0  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 1   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 2  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 3   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 4  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
#
#   first_shooter match_time
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
rgs_1['match_winner'] = np.where(rgs_1['home_score'] > rgs_1['away_score'], 'home win', np.where(rgs_1['home_score'] < rgs_1['away_score'], 'away win', 'draw'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rgs_1['match_winner'] = np.where(rgs_1['home_score'] > rgs_1['away_score'], 'home win', np.where(rgs_1['home_score'] < rgs_1['away_score'], 'away win', 'draw'))
#
# NameError: name 'np' is not defined

# %%
rgs_1['country_match_winner'] = np.where(rgs_1['home_score'] > rgs_1['away_score'], rgs_1['home_team'], np.where(rgs_1['home_score'] < rgs_1['away_score'], rgs_1['away_team'], np.NaN))

# %%
rgs_1.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral team scorer  minute own_goal penalty winner  \
# 0  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 1   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 2  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 3   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 4  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
#
#   first_shooter match_time match_winner country_match_winner
# ...

# %%
rgs_new = rgs_1.groupby(['country_match_winner']).size().to_frame('wins').reset_index()

# %%
rgs_new.head()
# Out:
#   country_match_winner  wins
# 0             Abkhazia    12
# 1          Afghanistan    38
# 2              Albania   176
# 3             Alderney     3
# 4              Algeria   390

# %%
rgs_new.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'match_winner_counter_csv'))

# %%
rgs_1.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'rgs_csv'))
