# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\asus\CareerFoundry\CareerFoundry Acheivement 6'

# %%
#"C:\Users\asus\CareerFoundry\CareerFoundry Acheivement 6\02 Data\Original Data\shootouts.csv"
df_shoot = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'shootouts.csv'), index_col = False)

# %%
df_shoot.head()
# Out:
#          date    home_team         away_team       winner first_shooter
# 0  1967-08-22        India            Taiwan       Taiwan           NaN
# 1  1971-11-14  South Korea  Vietnam Republic  South Korea           NaN
# 2  1972-05-07  South Korea              Iraq         Iraq           NaN
# 3  1972-05-17     Thailand       South Korea  South Korea           NaN
# 4  1972-05-19     Thailand          Cambodia     Thailand           NaN

# %%
df_shoot
# Out:
#            date      home_team         away_team       winner first_shooter
# 0    1967-08-22          India            Taiwan       Taiwan           NaN
# 1    1971-11-14    South Korea  Vietnam Republic  South Korea           NaN
# 2    1972-05-07    South Korea              Iraq         Iraq           NaN
# 3    1972-05-17       Thailand       South Korea  South Korea           NaN
# 4    1972-05-19       Thailand          Cambodia     Thailand           NaN
# ..          ...            ...               ...          ...           ...
# 557  2023-07-12  United States            Panama       Panama           NaN
# 558  2023-09-07           Iraq             India         Iraq           NaN
# 559  2023-09-10       Thailand              Iraq         Iraq           NaN
# 560  2023-10-13           Iraq             Qatar        Qatar           NaN
# 561  2023-11-21         Mexico          Honduras       Mexico           NaN
#
# [562 rows x 5 columns]

# %%
df_shoot.describe()
# Out:
#               date     home_team away_team     winner first_shooter
# count          562           562       562        562            86
# unique         498           165       178        163            29
# top     2016-06-03  South Africa    Uganda  Argentina      Colombia
# freq             5            15        15         14             9

# %%
#"C:\Users\asus\CareerFoundry\CareerFoundry Acheivement 6\02 Data\Original Data\results.csv.zip"
df_result = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'results.csv.zip'), index_col = False)

# %%
df_result.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df_result.describe()
# Out:
#          home_score    away_score
# count  45315.000000  45315.000000
# mean       1.739314      1.178241
# std        1.746904      1.392095
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df_scorers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'goalscorers.csv.zip'), index_col = False)

# %%
df_scorers.tail()
# Out:
#              date home_team    away_team     team             scorer  minute  \
# 43184  2023-11-21    Greece       France   France    Youssouf Fofana    74.0
# 43185  2023-11-21    Kosovo      Belarus  Belarus  Dmitry Antilevsky    43.0
# 43186  2023-11-21   Romania  Switzerland  Romania       Denis Alibec    50.0
# 43187  2023-11-21     Wales       Turkey    Wales      Neco Williams     7.0
# 43188  2023-11-21     Wales       Turkey   Turkey       Yusuf Yazıcı    70.0
#
#       own_goal penalty
# 43184    False   False
# 43185    False   False
# 43186    False   False
# 43187    False   False
# 43188    False    True

# %%
df_scorers.describe()
# Out:
#              minute
# count  42929.000000
# mean      50.040206
# std       26.363782
# min        1.000000
# 25%       28.000000
# 50%       51.000000
# 75%       73.000000
# max      122.000000

# %% [markdown]
# # Merging Data

# %%
# df.merge(df_2, on = ['customer_id', 'month'], how = 'inner')
# pd.merge(df,df_2, on = ['customer_id', 'month'], indicator = True)
pd.merge(df_result, df_scorers, on = ['date', 'home_team', 'away_team'], how = 'left')
# Out:
#              date home_team    away_team  home_score  away_score  \
# 0      1872-11-30  Scotland      England           0           0
# 1      1873-03-08   England     Scotland           4           2
# 2      1874-03-07  Scotland      England           2           1
# 3      1875-03-06   England     Scotland           2           2
# 4      1876-03-04  Scotland      England           3           0
# ...           ...       ...          ...         ...         ...
# 74513  2023-11-21   Croatia      Armenia           1           0
# 74514  2023-11-21   Andorra       Israel           0           2
# 74515  2023-11-21   Andorra       Israel           0           2
# 74516  2023-11-21    Kosovo      Belarus           0           1
# 74517  2023-11-21   Romania  Switzerland           1           0
#
#                     tournament              city   country  neutral     team  \
# 0                     Friendly           Glasgow  Scotland    False      NaN
# ...

# %%
df_result_scorers = df_result.merge(df_scorers, on = ['date', 'home_team', 'away_team'], how = 'left')

# %%
df_result_scorers
# Out:
#              date home_team    away_team  home_score  away_score  \
# 0      1872-11-30  Scotland      England           0           0
# 1      1873-03-08   England     Scotland           4           2
# 2      1874-03-07  Scotland      England           2           1
# 3      1875-03-06   England     Scotland           2           2
# 4      1876-03-04  Scotland      England           3           0
# ...           ...       ...          ...         ...         ...
# 74513  2023-11-21   Croatia      Armenia           1           0
# 74514  2023-11-21   Andorra       Israel           0           2
# 74515  2023-11-21   Andorra       Israel           0           2
# 74516  2023-11-21    Kosovo      Belarus           0           1
# 74517  2023-11-21   Romania  Switzerland           1           0
#
#                     tournament              city   country  neutral     team  \
# 0                     Friendly           Glasgow  Scotland    False      NaN
# ...

# %%
# pd.merge(df,df_2, on = ['customer_id', 'month'], indicator = True)

pd.merge(df_result_scorers,df_shoot, on = ['date', 'home_team', 'away_team'], how = 'left')
# Out:
#              date home_team    away_team  home_score  away_score  \
# 0      1872-11-30  Scotland      England           0           0
# 1      1873-03-08   England     Scotland           4           2
# 2      1874-03-07  Scotland      England           2           1
# 3      1875-03-06   England     Scotland           2           2
# 4      1876-03-04  Scotland      England           3           0
# ...           ...       ...          ...         ...         ...
# 74513  2023-11-21   Croatia      Armenia           1           0
# 74514  2023-11-21   Andorra       Israel           0           2
# 74515  2023-11-21   Andorra       Israel           0           2
# 74516  2023-11-21    Kosovo      Belarus           0           1
# 74517  2023-11-21   Romania  Switzerland           1           0
#
#                     tournament              city   country  neutral     team  \
# 0                     Friendly           Glasgow  Scotland    False      NaN
# ...

# %%
# df_result_scorers = df_result.merge(df_scorers, on = ['date', 'home_team', 'away_team'], how = 'left')
df_all_rgs = df_result_scorers.merge(df_shoot, on = ['date', 'home_team', 'away_team'], how = 'left')

# %%
df_all_rgs
# Out:
#              date home_team    away_team  home_score  away_score  \
# 0      1872-11-30  Scotland      England           0           0
# 1      1873-03-08   England     Scotland           4           2
# 2      1874-03-07  Scotland      England           2           1
# 3      1875-03-06   England     Scotland           2           2
# 4      1876-03-04  Scotland      England           3           0
# ...           ...       ...          ...         ...         ...
# 74513  2023-11-21   Croatia      Armenia           1           0
# 74514  2023-11-21   Andorra       Israel           0           2
# 74515  2023-11-21   Andorra       Israel           0           2
# 74516  2023-11-21    Kosovo      Belarus           0           1
# 74517  2023-11-21   Romania  Switzerland           1           0
#
#                     tournament              city   country  neutral     team  \
# 0                     Friendly           Glasgow  Scotland    False      NaN
# ...

# %%
df_all_rgs[df_all_rgs['winner']== 'Argentina']
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 15548  1977-03-22    Argentina         Iran           1           1
# 16736  1979-05-22    Argentina  Netherlands           0           0
# 24669  1990-06-30   Yugoslavia    Argentina           0           0
# 24676  1990-07-03        Italy    Argentina           1           1
# 24677  1990-07-03        Italy    Argentina           1           1
# 26780  1993-02-24    Argentina      Denmark           1           1
# 26781  1993-02-24    Argentina      Denmark           1           1
# 27578  1993-06-27       Brazil    Argentina           1           1
# 27579  1993-06-27       Brazil    Argentina           1           1
# 27595  1993-07-01     Colombia    Argentina           0           0
# 33876  1998-06-30    Argentina      England           2           2
# 33877  1998-06-30    Argentina      England           2           2
# 33878  1998-06-30    Argentina      England           2           2
# ...

# %%
# for col in df_test.columns.tolist():
 # weird = (df_test[[col]].applymap(type) != df_test[[col]].iloc[0].apply(type)).any(axis = 1)
  # if len (df_test[weird]) > 0:
  #  print (col)
    for col in df_all_rgs.columns.tolist():
  weird = (df_all_rgs[[col]].applymap(type) != df_all_rgs[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_all_rgs[weird]) > 0:
    print (col)
# Out:
#   File <tokenize>:6
#     weird = (df_all_rgs[[col]].applymap(type) != df_all_rgs[[col]].iloc[0].apply(type)).any(axis = 1)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
df_all_rgs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74518 entries, 0 to 74517
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           74518 non-null  object
#  1   home_team      74518 non-null  object
#  2   away_team      74518 non-null  object
#  3   home_score     74518 non-null  int64
#  4   away_score     74518 non-null  int64
#  5   tournament     74518 non-null  object
#  6   city           74518 non-null  object
#  7   country        74518 non-null  object
#  8   neutral        74518 non-null  bool
#  9   team           43189 non-null  object
#  10  scorer         43139 non-null  object
#  11  minute         42929 non-null  float64
#  12  own_goal       43187 non-null  object
#  13  penalty        43187 non-null  object
#  14  winner         769 non-null    object
#  15  first_shooter  182 non-null    object
# dtypes: bool(1), float64(1), int64(2), object(12)
# memory usage: 8.6+ MB

# %% [markdown]
# # Finding and Removing duplicates

# %%
# df_dups = df_prods_clean[df_prods_clean.duplicated()]
df_dups = df_all_rgs[df_all_rgs.duplicated()]

# %%
df_dups
# Out:
#              date    home_team            away_team  home_score  away_score  \
# 8369   1963-11-26        Ghana             Ethiopia           2           0
# 8374   1963-11-28     Ethiopia              Tunisia           4           2
# 8378   1963-11-28      Nigeria                Sudan           0           4
# 8729   1965-03-14     Suriname  Trinidad and Tobago           6           1
# 10279  1968-01-16        Congo                Ghana           1           3
# ...           ...          ...                  ...         ...         ...
# 73467  2023-06-18  Netherlands                Italy           2           3
# 73469  2023-06-18  Netherlands                Italy           2           3
# 73471  2023-06-18  Netherlands                Italy           2           3
# 73473  2023-06-18  Netherlands                Italy           2           3
# 73475  2023-06-18  Netherlands                Italy           2           3
#
# ...

# %%
pd.options.display.max_rows = None

# %%
df_all_rgs.shape
# Out:
# (74518, 16)

# %%
df_all_rgs_no_dups = df_all_rgs.drop_duplicates()

# %%
df_all_rgs_no_dups.shape
# Out:
# (74399, 16)

# %%
# df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'Ords_checked.csv'))
df_all_rgs.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'All_rgs.csv'))
