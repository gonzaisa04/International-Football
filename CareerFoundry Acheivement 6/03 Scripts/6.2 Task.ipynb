# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# "C:\Users\asus\CareerFoundry\CareerFoundry Acheivement 6\02 Data\Prepared Data\All_rgs.csv"
path = r'C:\Users\asus\CareerFoundry\CareerFoundry Acheivement 6'

# %%
rgs = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'All_rgs.csv'), index_col = False)

# %%
rgs.head()
# Out:
#    Unnamed: 0        date home_team away_team  home_score  away_score  \
# 0           0  1872-11-30  Scotland   England           0           0
# 1           1  1873-03-08   England  Scotland           4           2
# 2           2  1874-03-07  Scotland   England           2           1
# 3           3  1875-03-06   England  Scotland           2           2
# 4           4  1876-03-04  Scotland   England           3           0
#
#   tournament     city   country  neutral team scorer  minute own_goal penalty  \
# 0   Friendly  Glasgow  Scotland    False  NaN    NaN     NaN      NaN     NaN
# 1   Friendly   London   England    False  NaN    NaN     NaN      NaN     NaN
# 2   Friendly  Glasgow  Scotland    False  NaN    NaN     NaN      NaN     NaN
# 3   Friendly   London   England    False  NaN    NaN     NaN      NaN     NaN
# 4   Friendly  Glasgow  Scotland    False  NaN    NaN     NaN      NaN     NaN
#
#   winner first_shooter match_time
# 0    NaN           NaN        NaN
# ...

# %%
#result = []

#for value in ords_prods_merge["orders_day_of_week"]:
 # if value == 0:
  #  result.append("Busiest day")
  #elif value == 4:
   # result.append("Least busy")
  #else:
   # result.append("Regularly busy")
results = []

# %%
rgs.columns
# Out:
# Index(['Unnamed: 0', 'date', 'home_team', 'away_team', 'home_score',
#        'away_score', 'tournament', 'city', 'country', 'neutral', 'team',
#        'scorer', 'minute', 'own_goal', 'penalty', 'winner', 'first_shooter',
#        'match_time'],
#       dtype='object')

# %%
rgs.dtypes
# Out:
# Unnamed: 0         int64
# date              object
# home_team         object
# away_team         object
# home_score         int64
# away_score         int64
# tournament        object
# city              object
# country           object
# neutral             bool
# team              object
# scorer            object
# minute           float64
# own_goal          object
# penalty           object
# winner            object
# first_shooter     object
# match_time        object
# dtype: object

# %%
#df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
rgs = rgs.drop(columns = ['Unnamed: 0'])

# %%
rgs.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'rgs_checked.csv'))

# %%
rgs.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral team scorer  minute own_goal penalty winner  \
# 0  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 1   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 2  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
# 3   England    False  NaN    NaN     NaN      NaN     NaN    NaN
# 4  Scotland    False  NaN    NaN     NaN      NaN     NaN    NaN
#
#   first_shooter match_time
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
rgs_sub = rgs[['home_score','away_score', 'neutral', 'minute']]

# %%
rgs_sub.head()
# Out:
#    home_score  away_score  neutral  minute
# 0           0           0    False     NaN
# 1           4           2    False     NaN
# 2           2           1    False     NaN
# 3           2           2    False     NaN
# 4           3           0    False     NaN

# %%
rgs_sub.corr()
# Out:
#             home_score  away_score   neutral    minute
# home_score    1.000000   -0.255681 -0.058297 -0.011529
# away_score   -0.255681    1.000000  0.117689  0.003004
# neutral      -0.058297    0.117689  1.000000  0.014767
# minute       -0.011529    0.003004  0.014767  1.000000

# %%
plt.matshow(rgs_sub.corr())

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(rgs_sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# ## As the graph gets brighter, there is a stronger correlation between the variables. All the boxes being some variation of purple means there is no strong correlation one way or the other.

# %%
sns.lmplot(x = 'home_score', y = 'away_score', data = rgs)
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
rgs[rgs['home_score'] >= 10]
# Out:
#              date home_team         away_team  home_score  away_score  \
# 56     1888-03-03     Wales  Northern Ireland          11           0
# 121    1899-02-18   England  Northern Ireland          13           2
# 133    1901-02-23  Scotland  Northern Ireland          11           0
# 224    1908-07-12    Sweden            Norway          11           3
# 495    1917-10-07   Denmark            Norway          12           0
# ...           ...       ...               ...         ...         ...
# 74370  2023-11-18    France         Gibraltar          14           0
# 74371  2023-11-18    France         Gibraltar          14           0
# 74372  2023-11-18    France         Gibraltar          14           0
# 74373  2023-11-18    France         Gibraltar          14           0
# 74374  2023-11-18    France         Gibraltar          14           0
#
#                       tournament        city   country  neutral    team  \
# ...

# %%
pp = sns.pairplot(rgs_sub)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(rgs['minute'], bins = 8,kde = True)
# Out:
# <Axes: xlabel='minute', ylabel='Count'>

# %% [markdown]
# ## This graph shows that as the match gets later, there tends to be more goals, although not by much. There also seems to be a significant increase of goals in the last 15 minutes of regular time.

# %%
#df.loc[(df['Price per unit'] >= 20) & (df['Price per unit'] < 50), 'Price category'] = 'Middle price'
#df.loc[df['Price per unit'] >= 50, 'Price category'] = 'High price'
rgs.loc[rgs['minute'] <= 30, 'match_time'] = 'early'

# %%
rgs.loc[(rgs['minute'] > 30) & (rgs['minute'] <= 60), 'match_time'] = 'middle'

# %%
rgs.loc[(rgs['minute'] > 60) & (rgs['minute'] <= 90), 'match_time'] = 'late'

# %%
rgs.loc[rgs['minute'] > 90, 'match_time'] = 'extra time'

# %%
rgs.tail()
# Out:
#              date home_team    away_team  home_score  away_score  \
# 74513  2023-11-21   Croatia      Armenia           1           0
# 74514  2023-11-21   Andorra       Israel           0           2
# 74515  2023-11-21   Andorra       Israel           0           2
# 74516  2023-11-21    Kosovo      Belarus           0           1
# 74517  2023-11-21   Romania  Switzerland           1           0
#
#                     tournament              city  country  neutral     team  \
# 74513  UEFA Euro qualification            Zagreb  Croatia    False  Croatia
# 74514  UEFA Euro qualification  Andorra la Vella  Andorra    False   Israel
# 74515  UEFA Euro qualification  Andorra la Vella  Andorra    False   Israel
# 74516  UEFA Euro qualification          Pristina   Kosovo    False  Belarus
# 74517  UEFA Euro qualification         Bucharest  Romania    False  Romania
#
#                   scorer  minute own_goal penalty winner first_shooter  \
# ...

# %%
rgs['match_time'].value_counts(dropna = False)
# Out:
# match_time
# NaN           31589
# late          16528
# middle        14268
# early         11894
# extra time      239
# Name: count, dtype: int64

# %%
rgs.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral', 'team', 'scorer', 'minute',
#        'own_goal', 'penalty', 'winner', 'first_shooter', 'match_time'],
#       dtype='object')

# %%
sns.histplot(rgs['match_time'], kde = True)
# Out:
# <Axes: xlabel='match_time', ylabel='Count'>

# %%
rgs.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'All_rgs.csv'))

# %% [markdown]
# # None of the original questions were able to be answered through the analysis of this task. Through this task, more questions were asked and some where answered. Some questions asked and answered were
# ## 1. When are most scored? A: In the late stage of the match
# ## 2. Do goals increase as the games go on? A: Yes!
# # Other questions were asked as well, including:
# ## 1. What specific time has the most goals
# ## 2. Does the first to score often win?
# ## 3. Does extra time shift momentum of the game?
# ## 4. Who is the best at comeback wins?
# # Hypothesis
# ## The first team to score wins the match.
